# %% [markdown]
# # Get Supported Languages — Azure AI Translator
#
# This notebook queries the Azure Translator service for the full list of languages available for translation and transliteration.
#
# No authentication key is required for this endpoint — it is publicly accessible.

# %%
# %pip install azure-ai-translation-text azure-core python-dotenv --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\w\repos\foundry-tools\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import os
from azure.ai.translation.text import TextTranslationClient
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())  # loads .env from repo root

api_key = os.environ["AZURE_TRANSLATOR_KEY"]
region = os.environ["AZURE_TRANSLATOR_REGION"]

credential = AzureKeyCredential(api_key)
client = TextTranslationClient(credential=credential, region=region)
print("Translator client ready.")
# Out:
# Translator client ready.

# %%
# Retrieve the full list of supported languages
try:
    response = client.get_supported_languages()

    translation_count = len(response.translation) if response.translation else 0
    transliteration_count = len(response.transliteration) if response.transliteration else 0

    print(f"Languages supported for translation   : {translation_count}")
    print(f"Languages supported for transliteration: {transliteration_count}")

except HttpResponseError as exc:
    if exc.error:
        print(f"Error {exc.error.code}: {exc.error.message}")
    raise
# Out:
# Languages supported for translation   : 137
# Languages supported for transliteration: 42

# %%
# Print the first 20 translation languages
if response.translation:
    print("\nFirst 20 translation languages:")
    for code, lang in list(response.translation.items())[:20]:
        print(f"  {code:8s} — {lang.name} ({lang.native_name})")
# Out:
# First 20 translation languages:
#   af       — Afrikaans (Afrikaans)
#   am       — Amharic (አማርኛ)
#   ar       — Arabic (العربية)
#   as       — Assamese (অসমীয়া)
#   az       — Azerbaijani (Azərbaycan)
#   ba       — Bashkir (Bashkir)
#   be       — Belarusian (беларуская)
#   bg       — Bulgarian (Български)
#   bho      — Bhojpuri (भोजपुरी)
#   bn       — Bangla (বাংলা)
#   bo       — Tibetan (བོད་སྐད་)
#   brx      — Bodo (बड़ो)
#   bs       — Bosnian (Bosanski)
#   ca       — Catalan (Català)
#   cs       — Czech (Čeština)
#   cy       — Welsh (Cymraeg)
#   da       — Danish (Dansk)
#   de       — German (Deutsch)
#   doi      — Dogri (डोगरी)
#   dsb      — Lower Sorbian (Dolnoserbšćina)

# %%
# Print the transliteration languages and their scripts
if response.transliteration:
    print("\nTransliteration languages:")
    for code, lang in response.transliteration.items():
        script_names = ", ".join(s.name for s in lang.scripts) if lang.scripts else "(none)"
        print(f"  {code:8s} — {lang.name} | scripts: {script_names}")
# Out:
# Transliteration languages:
#   ar       — Arabic | scripts: Arabic, Latin
#   as       — Assamese | scripts: Bengali, Latin
#   be       — Belarusian | scripts: Cyrillic, Latin
#   bg       — Bulgarian | scripts: Cyrillic, Latin
#   bn       — Bangla | scripts: Bengali, Latin
#   brx      — Bodo | scripts: Devanagari, Latin
#   el       — Greek | scripts: Greek, Latin
#   fa       — Persian | scripts: Arabic, Latin
#   gom      — Konkani | scripts: Devanagari, Latin
#   gu       — Gujarati | scripts: Gujarati, Latin
#   he       — Hebrew | scripts: Hebrew, Latin
#   hi       — Hindi | scripts: Devanagari, Latin
#   ja       — Japanese | scripts: Japanese, Latin
#   kk       — Kazakh | scripts: Cyrillic, Latin
#   kn       — Kannada | scripts: Kannada, Latin
#   ko       — Korean | scripts: Korean, Latin
#   ks       — Kashmiri | scripts: Arabic, Latin
#   ky       — Kyrgyz | scripts: Cyrillic, Latin
#   mai      — Maithili | scripts: Devanagari, Latin
#   mk       — Macedonian | scripts: Cyrillic, Latin
#   ml       — Malayalam | scripts: Malayalam, Latin
#   mn-Cyrl  — Mongolian (Cyrillic) | scripts: Cyrillic
#   mni      — Manipuri | scripts: Meetei Mayek, Latin
#   mr       — Marathi | scripts: Devanagari, Latin
#   ne       — Nepali | scripts: Devanagari, Latin
#   or       — Odia | scripts: Odia, Latin
#   pa       — Punjabi | scripts: Gurmukhi, Latin
#   ru       — Russian | scripts: Cyrillic, Latin
#   sa       — Sanskrit | scripts: Devanagari, Latin
#   sd       — Sindhi | scripts: Arabic, Latin
#   si       — Sinhala | scripts: Sinhala, Latin
#   sr-Cyrl  — Serbian (Cyrillic) | scripts: Cyrillic
#   sr-Latn  — Serbian (Latin) | scripts: Latin
#   ta       — Tamil | scripts: Tamil, Latin
#   te       — Telugu | scripts: Telugu, Latin
#   tg       — Tajik | scripts: Cyrillic, Latin
#   th       — Thai | scripts: Thai
#   tt       — Tatar | scripts: Cyrillic, Latin
#   uk       — Ukrainian | scripts: Cyrillic, Latin
#   ur       — Urdu | scripts: Arabic, Latin
#   zh-Hans  — Chinese Simplified | scripts: Simplified, Latin
#   zh-Hant  — Chinese Traditional | scripts: Traditional, Latin
